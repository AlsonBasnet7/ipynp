# %%
import requests

# %%
a = requests.get("https://books.toscrape.com/")

# %%
with open(f"htmls/page1.html", "w") as f:
    f.write(a.text)

# %%
#sending basic get requets
url = "https://books.toscrape.com/"
response = requests.get(url)

# %%
#print the HTML content

# %%
#print(response.text) The HTML content of the page as a string

# %%
#checking the reponse status

# %%
print(response.status_code)
# Out:
# 200

# %%
#the best pracitce to do this is 
if response.status_code==200:
    print("Page fetched successfully")
else:
    pritn("Failed to fetch the page.")
# Out:
# Page fetched successfully

# %%
#we can also use different reponse properties

# %%
#handling connection errors
# try:
#     resposnse= requests.get(url, timeout=5)
#     response.raise_for_status() #raise an HTTPerror for bad response
#     print(response.text)
# except requests.exceptions.RequestException as e:
#     print(f"An error occured:{e}")
